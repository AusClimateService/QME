# %%
import sys
import pandas as pd
import xarray as xr

# %%
cd ACS/Tools/Dataset_Finder
# Out:
# /home/565/ag0738/ACS/Tools/Dataset_Finder

# %%
# the preceeding cd line will depend on your working directory
from dataset_finder import *

# %%
chosen_var = "prsn"
chosen_ref = "BARRAR2"

# %%
# %%time
# all_dd_data = get_datasets("ACS_DD", ver = "v1-r1").includes(var = "psl").select(var = "psl")
# all_dd_data = get_datasets("ACS_DD", ver = "v1-r1").includes(var = "sfcWind", exact_match = True).select(var = "sfcWind", exact_match = True)
all_dd_data = get_datasets("ACS_DD", gcm = "ACCESS-CM2", scenario = ("ssp126", "ssp370"), timescale = "day", var = chosen_var, exact_match = True)
all_dd_data
# Out:
# CPU times: user 529 ms, sys: 162 ms, total: 691 ms
# Wall time: 1.26 s
#     grid      org    gcm         scenario    mdl_run    rcm            ver    timescale
# --  --------  -----  ----------  ----------  ---------  -------------  -----  -----------
#  0  AUST-05i  BOM    ACCESS-CM2  ssp126      r4i1p1f1   BARPA-R        v1-r1  day
#  1  AUST-05i  BOM    ACCESS-CM2  ssp370      r4i1p1f1   BARPA-R        v1-r1  day
#  2  AUST-05i  CSIRO  ACCESS-CM2  ssp126      r4i1p1f1   CCAM-v2203-SN  v1-r1  day
#  3  AUST-05i  CSIRO  ACCESS-CM2  ssp370      r4i1p1f1   CCAM-v2203-SN  v1-r1  day

# %%
# %%time
qme_data = get_datasets("ACS_BC", scenario = "ssp", bc = "QME", ref = chosen_ref, var = chosen_var, exact_match = True)
qme_data
# Out:
# CPU times: user 0 ns, sys: 40 ms, total: 40 ms
# Wall time: 106 ms

# %%
runs_to_do = all_dd_data.find_missing(qme_data)
runs_to_do
# Out:
#     grid      org    gcm         scenario    mdl_run    rcm            ver    timescale
# --  --------  -----  ----------  ----------  ---------  -------------  -----  -----------
#  0  AUST-05i  BOM    ACCESS-CM2  ssp126      r4i1p1f1   BARPA-R        v1-r1  day
#  1  AUST-05i  BOM    ACCESS-CM2  ssp370      r4i1p1f1   BARPA-R        v1-r1  day
#  2  AUST-05i  CSIRO  ACCESS-CM2  ssp126      r4i1p1f1   CCAM-v2203-SN  v1-r1  day
#  3  AUST-05i  CSIRO  ACCESS-CM2  ssp370      r4i1p1f1   CCAM-v2203-SN  v1-r1  day

# %%
keys = ("gcm", "scenario", "mdl_run", "org", "rcm")

with open("/home/565/ag0738/ACS/QME/NHP/jobs_template.sh", 'r') as file:
    template = file.read()

with open("/home/565/ag0738/ACS/QME/NHP/jobs_to_do.sh", 'w') as file:
    file.write(template)
    for dataset in runs_to_do:
        for var in dataset.get_info()["var"]:
            file.write('submit_jobs "{}" "{}" "{}" "{}" "{}" "{}" "{}"\n'.format(*[dataset.data[key] for key in keys], chosen_ref, var))
